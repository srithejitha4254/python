# %%
lst=[10,20,30]
print(lst)
print(type(lst))
# Out:
# [10, 20, 30]
# <class 'list'>

# %%
pavan=[10,20,30]
print(pavan)
print(type(pavan))
# Out:
# [10, 20, 30]
# <class 'list'>

# %%
a=[10,20,30]
print(a)
# Out:
# [10, 20, 30]

# %%
x=[12,19,71,-14,6,8,13,-76]
print(x[2]+x[3]-x[4]+x[6])
# Out:
# 64

# %%
my_list=[10,12.2,'hello',67.2,'123',True,796]
print(my_list[2])
print(type(my_list[2]))
print(my_list[4])
print(type(my_list[4]))
print(my_list[5])
print(type(my_list[5]))
# Out:
# hello
# <class 'str'>
# 123
# <class 'str'>
# True
# <class 'bool'>

# %%
x=(10,20,30)
print(x)
print(type(x))
# Out:
# (10, 20, 30)
# <class 'tuple'>

# %%
x=(10,20,30)
print(x[0])
# Out:
# 10

# %%
l=[10,20,30,40,50]
print(l)
print(type(l))
# Out:
# [10, 20, 30, 40, 50]
# <class 'list'>

# %%
s={10,20,30,40,10,10,10,10}
print(s)
print(type(s))
# Out:
# {40, 10, 20, 30}
# <class 'set'>

# %%
fruits={'apple','mango','orange','kiwi','dragon'}
print(fruits)
# Out:
# {'orange', 'dragon', 'apple', 'mango', 'kiwi'}

# %%
s1={10,20,30}
s2={30,40,50,10}
print(s1.intersection(s2))
# Out:
# {10, 30}

# %%
my_set={'a','a','a','a','a','a'}
print(my_set)
# Out:
# {'a'}

# %%
a='Lavya '
b='Madhavarapu'
print(a+b)
# Out:
# Lavya Madhavarapu
