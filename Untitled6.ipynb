# %%
from sklearn.datasets import fetch_2onewsgroups
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.navie_bayes import acccuracy_score , classification_report
categories = ['sci.electronics', 'comp.graphics', 'rec,hockey.sport','alt.athesim']
newsgroups = fetch_20newsgroups(subset= "all", categories = categories , shuffle = True,  random_state = 42)
print(f" Total documents : {len(newsgroup.data)})
print(f" Target names : (nwesgroups.target_names))
x_train , y_train , x_test, y_test = train_test_split (newsgroups.data , nwesgroups.target_names, text_size = 0.2, random_state = 42)
vectorizer = tfidf .vectorizer(stop_words)
