# %%
import pandas as pd
import numpy as np
data=pd.read_csv(r"C:\Users\student\Desktop\New folder (2)")
form sklearn.model_selection import
train_test_split
xtrain,xtest,ytrain,ytest=train_test_spilt
from sklearn.neighbors import KneighborsClassifer
RandomforestClassifer
LogisticRegression
a={}
for i in range(1,121):
    knn=KNegiborsClassifier(n_negihbors=i)
    knn.fit(xtrain,ytrain)
    ypred=knn.predict(xtest)
    from sklearn.metrics import accuracy_score 
    from sklearn.metrics import 
    multilabel_conusion_matrix(ytest,ytrain)
    print(accuracy_score(ytest,ypred)*100)
    a[i]=accuracy_score(ytest,ypred)*100
    b=[]
    for i in a:
        if a[i]==100:
            b.append(i)
    print(b)
